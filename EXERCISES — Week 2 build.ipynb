# %% [markdown]
# EXERCISE QUESTION

# %% [markdown]
# Q1

# %%
# missing report
import pandas as pd
print(df.isnull().sum())
# Out:
# order_id         0
# user_id          0
# weight_kg        0
# distance_km      0
# express_flag     0
# quantity         0
# price            0
# shipping_cost    0
# dtype: int64

# %%
#three named-question plots
plt.figure(figsize=(6,4))
plt.hist(df["distance_km"], bins=20)
plt.title("Distribution of Delivery Distance")
plt.xlabel("Distance (km)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["weight_kg"].dropna())
plt.title("Package Weight Box Plot")
plt.ylabel("Weight (kg)")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["distance_km"], df["shipping_cost"])
plt.xlabel("Distance")
plt.ylabel("Shipping Cost")
plt.title("Amount")
plt.show()

# %%
#correlation matrix
plt.figure(figsize=(8,6))
sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Q2

# %%
#Engineer the five features 
df["weight_per_item"] = df["weight_kg"] / df["quantity"]
print("package density")
# Out:
# package density

# %%
df["distance_per_item"] = df["distance_km"] / df["quantity"]
print("distance per item")
# Out:
# distance per item

# %%
df["heavy_package"] = df["weight_kg"] > 20
print("heavy package")
# Out:
# heavy package

# %%
df["express_heavy"] = (
    (df["express_flag"]=="Yes") &
    (df["weight_kg"]>20)
)
print("express and heavy")
# Out:
# express and heavy

# %%
df["large_order"] = df["quantity"] >= 5
print("large order")
# Out:
# large order
